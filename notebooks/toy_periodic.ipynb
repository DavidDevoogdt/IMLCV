# %%
# %load_ext autoreload

# %autoreload 2

# %%
from IMLCV.configs.config_general import config


config(
    env="local",
    local_ref_threads=2,
    max_threads_local=10,
)


# config(

#     singlepoint_nodes=2,
#     walltime="12:00:00",
#     bootstrap=False,
#     training_cores=16,

# )
# Out:
# ROOT_DIR=PosixPath('/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV')
# providing num=1 executors for label='training' with threads=10
# providing num=1 executors for label='default' with threads=2
# providing num=5 executors for label='reference' with threads=2
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor default failed due to: Workqueue Submit Process is not alive
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor training failed due to: Workqueue Submit Process is not alive
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor reference failed due to: Workqueue Submit Process is not alive

# %%
from IMLCV.examples.example_systems import toy_periodic_phase_trans
md,refs = toy_periodic_phase_trans()

refs[0].volume()
# Out:
# Array(182.20503404, dtype=float64)

# %%
md.run(1000)
# Out:
# running for 1000 steps!
# Both thermostat and barostat are present separately and will be merged
# Temperature coupling achieved through Langevin thermostat
# Pressure coupling achieved through Langevin barostat
#    step   | cons err | e_pot[Kj/mol] |e_bias[Kj/mol] |  P[bar]  |   T[K]   |walltime[s]||∇ₓUᵇ|[Kj/Å] |    CV
# ================================================================================================================
#        100|    0.0011|    46.35575735|     0.00000000   -2167.51     320.32       14.45|         0.00| [1201.82624685]
#        200|    0.0014|    71.96907960|     0.00000000    2163.62     408.94       23.71|         0.00| [1064.92423564]
#        300|    0.0017|    50.94500288|     0.00000000   -4262.08     291.89       33.14|         0.00| [1323.41038653]
#        400|    0.0016|    43.78522118|     0.00000000   -3573.96     187.29       42.64|         0.00| [1237.82925899]
#        500|    0.0014|    46.85363918|     0.00000000    -632.85     233.92       52.57|         0.00| [1131.77486061]
#        600|    0.0014|    51.98414353|     0.00000000     762.85     267.16       62.32|         0.00| [1014.60598751]
#        700|    0.0011|    66.25190386|     0.00000000    3385.48     403.38       72.52|         0.00| [1018.74797289]
#        800|    0.0012|    56.95712876|     0.00000000    2563.91     381.36       82.39|         0.00| [943.07566194]
#        900|    0.0011|    52.78120255|     0.00000000    -466.54     251.17       92.68|         0.00| [1069.9172986]
#       1000|    0.0011|    49.16463385|     0.00000000   -2164.91     237.66      104.16|         0.00| [1084.13302197]

# %%
from ase.visualize import view
view(md.sp.canonicalize()[0].to_ase(md.static_trajectory_info).repeat(2), viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 29.124889503832343">
#     <group/>
#   </viewpoint>
#   <transform translation="-5.458324369811585 -5.56871372235986 -5.515348008429691">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.91664873962317 -0.34467201038558226 0.7586417626587871 12.759112601096982 10.792755434334136 -1.4580644348625973 1.842463861473812 11.13742744471972 -2.2167061975213844 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.430492716203105 -3.4250173071964514 11.030696016859382">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.91664873962317 -0.34467201038558226 0.7586417626587871 12.759112601096982 10.792755434334136 -1.4580644348625973 1.842463861473812 11.13742744471972 -2.2167061975213844 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.91664873962317 -0.34467201038558226 0.7586417626587871 13.347141455826275 -3.7696893175820336 11.789337779518169 2.430492716203105 -3.4250173071964514 11.030696016859382 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="1.842463861473812 11.13742744471972 -2.2167061975213844">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.91664873962317 -0.34467201038558226 0.7586417626587871 13.347141455826275 -3.7696893175820336 11.789337779518169 2.430492716203105 -3.4250173071964514 11.030696016859382 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="4.9037958615317825 1.872296261346996 0.6727902741608738">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.14772960598634 0.7542784450576245 0.5156340173063361">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.740351427013326 4.701964571539768 0.07286969692864849">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="4.206311123873507 1.571201728194803 4.390972153124886">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.933776946559973 1.1554355820169881 3.593775555784428">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.2337734392958053 0.1022080442397237 3.0206307344453935">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.627843571002078 3.807719732590945 2.770392056728276">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="4.219897291563154 2.5590981197480804 1.458268130456212">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.119042219633335 0.15978760774877032 6.188138282590565">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.3629759640878927 -0.9582302085406011 6.030982025736027">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.955597785114878 2.989455917941542 5.58821770535834">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.42155748197506 -0.1413069254034227 9.906320161554577">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="7.149023304661525 -0.5570730715812375 9.10912356421412">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="4.449019797397358 -1.610300609358502 8.535978742875084">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="7.8430899291036305 2.095211078992719 8.285740065157967">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.435143649664706 0.8465894661498548 6.9736161388859035">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.825027792268688 7.441009983706856 -0.43556282459981843">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.068961536723246 6.3229921674174845 -0.5927190814543561">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.6615833577502315 10.270678293899628 -1.0354834018320438">

# %%
from pathlib import Path

from IMLCV.base.rounds import Rounds
from IMLCV.examples.example_systems import toy_periodic_phase_trans
from IMLCV.scheme import Scheme

folder = Path("perovskites")/"toy_periodic_2"

if folder.exists():
    scheme = Scheme( rounds= Rounds.create(folder=folder, copy=False, new_folder=False))

else:
    md,refs = toy_periodic_phase_trans()
    

    scheme = Scheme.from_refs(mde=md, refs=sum(*refs), folder=folder,steps=1000,)

# %%
from IMLCV.base.UnitsConstants import angstrom, boltzmann, kelvin, kjmol

300*kelvin*boltzmann/kjmol
# Out:
# 2.494341595946812

# %%
steps=2000

chunk_size=100


n=15

max_bias=150 * kjmol
samples_per_bin=200
min_samples_per_bin=5

n_max=2*n

# %%
15*2000/2000
# Out:
# 15.0

# %%
scheme.inner_loop(
    steps=steps,
    n=n,
    n_max_fes=n_max,
    convergence_kl=1e-4,
    chunk_size=100,
    eps_umbrella=0.10,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)
# Out:
# cv_round=0
# i_0=1
# running round i=1 with 2000 steps
# grid=[Array([  18.2205034 ,  162.76983041,  307.31915742,  451.86848443,
#         596.41781143,  740.96713844,  885.51646545, 1030.06579246,
#        1174.61511946, 1319.16444647, 1463.71377348, 1608.26310049,
#        1752.81242749, 1897.3617545 , 2041.91108151, 2186.46040852],      dtype=float64)]
# k*kjmol=Array([9.37096767e-11], dtype=float64)
# len(biases)=15
# got exception  while collecting md 7, round 1, cv 0, marking as invalid
# got exception  while collecting md 11, round 1, cv 0, marking as invalid
# estimating bias from koopman Theory!
# kl_div=Array(15.79871448, dtype=float64)
# running round i=2 with 2000 steps
# grid=[Array([  18.2205034 ,  162.76983041,  307.31915742,  451.86848443,
#         596.41781143,  740.96713844,  885.51646545, 1030.06579246,
#        1174.61511946, 1319.16444647, 1463.71377348, 1608.26310049,
#        1752.81242749, 1897.3617545 , 2041.91108151, 2186.46040852],      dtype=float64)]
# k*kjmol=Array([9.37096767e-11], dtype=float64)
# len(biases)=15
# Process WorkQueue-Submit-Process:
# Process WorkQueue-Submit-Process:
# Process WorkQueue-Submit-Process:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 861, in _work_queue_submit_wait
#     task = task_queue.get(timeout=1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 861, in _work_queue_submit_wait
#     task = task_queue.get(timeout=1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 970, in _work_queue_submit_wait
#     t = q.wait(1)
#         ^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1914, in wait
#     return self.wait_for_tag(None, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1928, in wait_for_tag
#     task_pointer = work_queue_wait_for_tag(self._work_queue, tag, timeout)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/cwork_queue.py", line 543, in work_queue_wait_for_tag
#     return _cwork_queue.work_queue_wait_for_tag(q, tag, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 scheme.inner_loop(
#       2     steps=steps,
#       3     n=n,
#       4     n_max_fes=n_max,
#       5     convergence_kl=1e-4,
#       6     chunk_size=100,
#       7     eps_umbrella=0.10,
#       8     max_bias=max_bias,
#       9     samples_per_bin=samples_per_bin,
#      10     min_samples_per_bin=min_samples_per_bin,
#      11 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:239, in Scheme.inner_loop(self, rnds, convergence_kl, steps, K, update_metric, n, samples_per_bin, min_samples_per_bin, init_max_grad, plot, choice, fes_bias_rnds, scale_n, cv_round, chunk_size, eps_umbrella, plot_margin, enforce_min_traj_length, recalc_cv, only_finished, plot_umbrella, max_bias, n_max_fes, thermolib, macro_chunk, T_scale, koopman, lag_n, koopman_wham, out, direct_bias, init, first_round_without_bias)
#     236 if without_bias:
#     237     print(f"running first round wihtout biases")
# --> 239 self.grid_umbrella(
#     240     steps=steps,
#     241     n=n,
#     242     k=K,
#     243     plot=plot_umbrella,
#     244     scale_n=scale_n,
#     245     cv_round=cv_round,
#     246     ignore_invalid=False,
#     247     eps=eps_umbrella if not without_bias else 1,
#     248     min_traj_length=steps if (i > 1 and enforce_min_traj_length) else None,
#     249     recalc_cv=recalc_cv,
#     250     only_finished=i > 1 and only_finished,
#     251     chunk_size=chunk_size,
#     252     T_scale=T_scale,
#     253     # use_fes_bias=True,
#     254 )
#     256 prev_bias = self.rounds.get_bias(c=cv_round, r=i)
#     258 new_bias = self.FESBias(
#     259     plot=plot,
#     260     samples_per_bin=samples_per_bin,
#    (...)    279     direct_bias=direct_bias,
#     280 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:138, in Scheme.grid_umbrella(self, steps, k, n, max_grad, plot, scale_n, cv_round, ignore_invalid, eps, min_traj_length, recalc_cv, only_finished, chunk_size, T_scale)
#     135 else:
#     136     sp0 = None
# --> 138 self.rounds.run_par(
#     139     biases=biases,
#     140     steps=steps,
#     141     plot=plot,
#     142     cv_round=cv_round,
#     143     ignore_invalid=ignore_invalid,
#     144     min_traj_length=min_traj_length,
#     145     recalc_cv=recalc_cv,
#     146     only_finished=only_finished,
#     147     sp0=sp0,
#     148     chunk_size=chunk_size,
#     149     T_scale=T_scale,
#     150     # use_fes_bias=True,
#     151 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/base/rounds.py:2051, in Rounds.run_par(self, biases, steps, plot, KEY, sp0, ignore_invalid, md_trajs, cv_round, wait_for_plots, min_traj_length, recalc_cv, only_finished, profile, chunk_size, T_scale, macro_chunk, lag_n, use_fes_bias)
#    2049 for i, future in tasks:
#    2050     try:
# -> 2051         future.result()
#    2053     except Exception as _:
#    2054         print(f"got exception  while collecting md {i}, round {r}, cv {cv_round}, marking as invalid")
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import ase


from IMLCV.base.UnitsConstants import electronvolt,kjmol,kelvin,boltzmann

kjmol

# ase.units.kJ/ase.units.mol
# Out:
# 0.0003808799176039228

# %%
300 * kelvin*boltzmann
# Out:
# 0.000950044621540259

# %%
from IMLCV.base.UnitsConstants import kjmol

new_bias = scheme.FESBias(
    thermolib=False,
    n_max=n_max,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)

scheme.rounds.add_round(bias=new_bias)
# Out:
# estimating bias from koopman Theory!
