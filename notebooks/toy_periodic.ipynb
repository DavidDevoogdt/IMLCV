# %%
# %load_ext autoreload

# %autoreload 2

# %%
from IMLCV.configs.config_general import config

config(

    singlepoint_nodes=2,
    walltime="12:00:00",
    bootstrap=False,
    training_cores=16,

)
# Out:
# ROOT_DIR=PosixPath('/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV')
# node
# stevin
# executor='work_queue'
# wall_time_s=14160.0
# executor='work_queue'
# wall_time_s=42960.0
# executor='work_queue'
# wall_time_s=14160.0
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(

# %%
from IMLCV.examples.example_systems import toy_periodic_phase_trans
md,refs = toy_periodic_phase_trans()

refs[0].volume()
# Out:
# Array(182.20503404, dtype=float64)

# %%
md.run(100)
# Out:
# running for 100 steps!
# Both thermostat and barostat are present separately and will be merged
# Temperature coupling achieved through Langevin thermostat
# Pressure coupling achieved through Langevin barostat
#    step   | cons err | e_pot[Kj/mol] |e_bias[Kj/mol] |  P[bar]  |   T[K]   |walltime[s]||∇ₓUᵇ|[Kj/Å] |    CV
# ================================================================================================================
#        100|    0.0244|    42.59880527|     0.00000000 -205053.92     219.68       14.28|         0.00| [163.35237562]

# %%
from ase.visualize import view
view(md.sp.canonicalize()[0].to_ase(md.static_trajectory_info).repeat(2), viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 14.070584701550573">
#     <group/>
#   </viewpoint>
#   <transform translation="0.42810157468484267 0.4488776701702547 2.967450838990257">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -0.8562031493696853 -5.657164067279625 -0.317042583921184 -6.691363766221702 -6.554919407620135 0.0504496676765242 -5.835160616852017 -0.8977553403405094 0.3674922515977082 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.5564360476737558 -0.41726864819229176 -5.934901677980514">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -0.8562031493696853 -5.657164067279625 -0.317042583921184 -6.691363766221702 -6.554919407620135 0.0504496676765242 -5.835160616852017 -0.8977553403405094 0.3674922515977082 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -0.8562031493696853 -5.657164067279625 -0.317042583921184 -0.29976710169592957 -6.074432715471917 -6.2519442619016985 0.5564360476737558 -0.41726864819229176 -5.934901677980514 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="-5.835160616852017 -0.8977553403405094 0.3674922515977082">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -0.8562031493696853 -5.657164067279625 -0.317042583921184 -0.29976710169592957 -6.074432715471917 -6.2519442619016985 0.5564360476737558 -0.41726864819229176 -5.934901677980514 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="-2.6735896885838746 -3.0620528146327826 -2.804182483058327">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.7814227335340547 -0.4159920500254402 -2.792412529582185">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.04143899760296799 -1.096586995305627 -2.725562583353471">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.7633818987692766 -1.5537499292335877 0.02385325148779997">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-3.133174419990679 -3.220584483990245 -1.3053841557923334">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.6991400115936703 -2.9313007375140785 -1.6012014768605984">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.42818042685967134 -1.3722539721243254 -1.248791721808726">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.8749668896245675 -1.465713018442065 -1.5515006227433175">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.395371664746997 -3.2706871387289285 -5.771633322048585">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.5032047096971768 -0.6246263741215861 -5.759863368572442">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.2367790262339099 -1.305221319401773 -5.6930134223437285">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.4851638749323988 -1.7623842533297336 -2.9435975875024574">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.854956396153801 -3.429218808086391 -4.27283499478259">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.4209219877567925 -3.1399350616102244 -4.568652315850856">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.14996240302279346 -1.5808882962204713 -4.2162425607989835">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.5967488657876896 -1.674347342538211 -4.518951461733574">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-5.591169997009883 -3.5109304848030374 -2.620436357259473">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-3.6990030419600632 -0.864869720195695 -2.6086664037833307">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transf

# %%
from pathlib import Path

from IMLCV.base.rounds import Rounds
from IMLCV.examples.example_systems import toy_periodic_phase_trans
from IMLCV.scheme import Scheme

folder = Path("perovskites")/"toy_periodic_2"

if folder.exists():
    scheme = Scheme( rounds= Rounds.create(folder=folder, copy=False, new_folder=False))

else:
    md,refs = toy_periodic_phase_trans()
    

    scheme = Scheme.from_refs(mde=md, refs=sum(*refs), folder=folder,steps=1000,)

# %%
from IMLCV.base.UnitsConstants import kelvin,boltzmann, kjmol,angstrom

300*kelvin*boltzmann/kjmol
# Out:
# 2.494341595946812

# %%
steps=2000

chunk_size=100

max_bias=150 * kjmol
samples_per_bin=20
min_samples_per_bin=5

# %%
scheme.inner_loop(
    steps=steps,
    n=32,
    convergence_kl=1e-4,
    chunk_size=100,
    eps_umbrella=0.10,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)
# Out:
# cv_round=0
# i_0=1
# running round i=1 with 2000 steps
# grid=[Array([ 145.76402723,  195.8704116 ,  245.97679596,  296.08318032,
#         346.18956468,  396.29594904,  446.40233341,  496.50871777,
#         546.61510213,  596.72148649,  646.82787085,  696.93425521,
#         747.04063958,  797.14702394,  847.2534083 ,  897.35979266,
#         947.46617702,  997.57256139, 1047.67894575, 1097.78533011,
#        1147.89171447, 1197.99809883, 1248.10448319, 1298.21086756,
#        1348.31725192, 1398.42363628, 1448.53002064, 1498.636405  ,
#        1548.74278937, 1598.84917373, 1648.95555809, 1699.06194245,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([7.79884801e-10], dtype=float64)
# len(biases)=32

# %%
import ase


from IMLCV.base.UnitsConstants import electronvolt,kjmol,kelvin,boltzmann

kjmol

# ase.units.kJ/ase.units.mol
# Out:
# 0.0003808799176039228

# %%
300 * kelvin*boltzmann
# Out:
# 0.000950044621540259

# %%
from IMLCV.base.UnitsConstants import kjmol

new_bias = scheme.FESBias(
    thermolib=False,
    n_max=1e5,
    # start_r=0,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)

scheme.rounds.add_round(bias=new_bias)
# Out:
# estimating bias from koopman Theory!
