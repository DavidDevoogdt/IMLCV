# %%
# %load_ext autoreload

# %autoreload 2

# %%
from IMLCV.configs.config_general import config

config(

    singlepoint_nodes=2,
    walltime="12:00:00",
    bootstrap=False,
    training_cores=16,

)
# Out:
# ROOT_DIR=PosixPath('/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV')
# node
# stevin
# executor='work_queue'
# wall_time_s=14160.0
# executor='work_queue'
# wall_time_s=42960.0
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# executor='work_queue'
# wall_time_s=14160.0
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(

# %%
from IMLCV.examples.example_systems import toy_periodic_phase_trans
md,refs = toy_periodic_phase_trans()

refs[0].volume()
# Out:
# Array(182.20503404, dtype=float64)

# %%
md.run(1000)
# Out:
# running for 1000 steps!
# Both thermostat and barostat are present separately and will be merged
# Temperature coupling achieved through Langevin thermostat
# Pressure coupling achieved through Langevin barostat
#    step   | cons err | e_pot[Kj/mol] |e_bias[Kj/mol] |  P[bar]  |   T[K]   |walltime[s]||∇ₓUᵇ|[Kj/Å] |    CV
# ================================================================================================================
#        100|    0.0128|    24.46139451|     0.00000000  -71586.72     316.09        9.21|         0.00| [162.72413675]
#        200|    0.0158|    16.70670755|     0.00000000  -35718.20     322.20       14.96|         0.00| [165.36362419]
#        300|    0.0158|    34.43883108|     0.00000000  -44132.03     314.10       21.20|         0.00| [147.21613591]
#        400|    0.0233|    24.49784332|     0.00000000  -48128.53     349.97       27.35|         0.00| [158.45277339]
#        500|    0.0264|    28.39647960|     0.00000000   43928.78     254.46       34.00|         0.00| [154.55951901]
#        600|    0.0291|    27.26314660|     0.00000000  -16987.89     136.24       40.66|         0.00| [149.32928958]
#        700|    0.0294|    22.95707330|     0.00000000  -22815.54     226.03       47.93|         0.00| [153.86637037]
#        800|    0.0315|    43.10738944|     0.00000000  -87020.30     251.23       54.76|         0.00| [166.4471691]
#        900|    0.0358|    24.36715624|     0.00000000  -48451.47     361.10       61.59|         0.00| [173.63337129]
#       1000|    0.0386|    29.12723261|     0.00000000   65408.56     267.85       68.81|         0.00| [164.82130398]

# %%
from ase.visualize import view
view(md.sp.canonicalize()[0].to_ase(md.static_trajectory_info).repeat(2), viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 16.840585385419867">
#     <group/>
#   </viewpoint>
#   <transform translation="2.750604069247418 0.3712490856563128 -0.8057359650035595">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -5.501208138494836 -0.7881516708909467 1.874168514140842 -6.605202745561652 -1.5306498422035724 -3.8741063074406092 -1.1039946070668154 -0.7424981713126256 -5.748274821581451 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.07577521482378864 -5.704209889684594 1.611471930007119">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -5.501208138494836 -0.7881516708909467 1.874168514140842 -6.605202745561652 -1.5306498422035724 -3.8741063074406092 -1.1039946070668154 -0.7424981713126256 -5.748274821581451 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -5.501208138494836 -0.7881516708909467 1.874168514140842 -5.425432923671048 -6.4923615605755405 3.485640444147961 0.07577521482378864 -5.704209889684594 1.611471930007119 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="-1.1039946070668154 -0.7424981713126256 -5.748274821581451">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 -5.501208138494836 -0.7881516708909467 1.874168514140842 -5.425432923671048 -6.4923615605755405 3.485640444147961 0.07577521482378864 -5.704209889684594 1.611471930007119 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="-0.667691200157175 -2.878472613395944 -0.35337942805850553">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.0550025965115992 -3.2079379096123075 0.22688537441031026">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.5984650158980979 -1.544831151568313 -0.8796387392154531">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.0409124449098575 -1.8656338929843561 -0.5262337502792094">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.7452448071818377 -0.49997492383167397 -2.559823679755247">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.183882423068261 -3.28789020409972 -1.3472502222802147">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.17678568822596225 -1.6785328555784644 0.5277757809001768">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.7005041309686406 -1.5298711942557772 0.9291976490545031">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.6298035927452806 -5.730577558238242 0.45235653694505396">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.017114989099705 -6.060042854454604 1.0326213394138697">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.5605774084862035 -4.39693609641061 -0.07390277421189362">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.0030248374979633 -4.717738837826653 0.2795022147243501">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.7073571997699434 -3.352079868673971 -1.7540877147516873">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.145994815656367 -6.139995148942017 -0.5415142572766553">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.13889808081406793 -4.530637800420761 1.3335117459037362">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.6626165235567463 -4.381976139098074 1.7349336140580625">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-1.2196885036905827 -3.249721699052257 -3.227516838849231">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-2.606999900045007 -3.5791869952686204 -2.6472520363804155">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform transla

# %%
md.sp
# Out:
# SystemParams(coordinates=Array([[ -6.82855684,  -5.08996202,  -6.0862833 ],
#        [ -7.8493369 ,  -2.80818785,  -4.71911288],
#        [ -9.04026957,  -0.10390093,   6.56846502],
#        [  1.40417713,  -0.49482579,   3.39315942],
#        [-16.65620004,  -0.43672162,   3.13884548],
#        [ -3.24714973,  -5.42628377, -15.61224156],
#        [-12.40599789,  -0.22851646,  -7.97118803],
#        [-11.89919944,   4.17420654,   1.32753851]], dtype=float64), cell=Array([[-5.8836099 , -1.97827173,  0.84645896],
#        [ 0.        , -7.00338391, -0.05118248],
#        [ 0.        ,  0.        , -6.11839494]], dtype=float64))

# %%
md.get_energy(gpos=True,vtens=True)
# Out:
# EnergyResult(energy=Array(0.00775246, dtype=float64), gpos=Array([[ 0.00423517, -0.00682901, -0.00778652],
#        [-0.00142994, -0.00162616, -0.00383034],
#        [-0.00222392,  0.0068338 ,  0.00493547],
#        [-0.00295764, -0.00148928,  0.00512087],
#        [-0.00528868,  0.00060563,  0.0046272 ],
#        [ 0.00654083,  0.00154041,  0.00294853],
#        [-0.00703925, -0.00112955, -0.00078562],
#        [ 0.00816343,  0.00209416, -0.00522958]], dtype=float64), vtens=Array([[ 0.03971328,  0.01524695,  0.01748869],
#        [ 0.01524695, -0.05999605, -0.05783961],
#        [ 0.01748869, -0.05783961, -0.05941624]], dtype=float64))

# %%
from pathlib import Path

from IMLCV.base.rounds import Rounds
from IMLCV.examples.example_systems import toy_periodic_phase_trans
from IMLCV.scheme import Scheme

folder = Path("perovskites")/"toy_periodic_2"

if folder.exists():
    scheme = Scheme( rounds= Rounds.create(folder=folder, copy=False, new_folder=False))

else:
    md,refs = toy_periodic_phase_trans()
    

    scheme = Scheme.from_refs(mde=md, refs=sum(*refs), folder=folder,steps=1000,)

# %%
from IMLCV.base.UnitsConstants import kelvin,boltzmann, kjmol,angstrom

300*kelvin*boltzmann/kjmol
# Out:
# 2.494341595946812

# %%
steps=2000

chunk_size=100

max_bias=150 * kjmol
samples_per_bin=20
min_samples_per_bin=5

# %%
scheme.inner_loop(
    steps=steps,
    n=32,
    convergence_kl=1e-4,
    chunk_size=100,
    eps_umbrella=0.10,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)
# Out:
# cv_round=0
# i_0=1
# running round i=1 with 1000 steps
# grid=[Array([ 145.76402723,  195.8704116 ,  245.97679596,  296.08318032,
#         346.18956468,  396.29594904,  446.40233341,  496.50871777,
#         546.61510213,  596.72148649,  646.82787085,  696.93425521,
#         747.04063958,  797.14702394,  847.2534083 ,  897.35979266,
#         947.46617702,  997.57256139, 1047.67894575, 1097.78533011,
#        1147.89171447, 1197.99809883, 1248.10448319, 1298.21086756,
#        1348.31725192, 1398.42363628, 1448.53002064, 1498.636405  ,
#        1548.74278937, 1598.84917373, 1648.95555809, 1699.06194245,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([7.79884801e-10], dtype=float64)
# len(biases)=32
# estimating bias from koopman Theory!
# kl_div=Array(76.22237137, dtype=float64)
# running round i=2 with 1000 steps
# grid=[Array([ 145.76402723,  195.8704116 ,  245.97679596,  296.08318032,
#         346.18956468,  396.29594904,  446.40233341,  496.50871777,
#         546.61510213,  596.72148649,  646.82787085,  696.93425521,
#         747.04063958,  797.14702394,  847.2534083 ,  897.35979266,
#         947.46617702,  997.57256139, 1047.67894575, 1097.78533011,
#        1147.89171447, 1197.99809883, 1248.10448319, 1298.21086756,
#        1348.31725192, 1398.42363628, 1448.53002064, 1498.636405  ,
#        1548.74278937, 1598.84917373, 1648.95555809, 1699.06194245,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([7.79884801e-10], dtype=float64)
# len(biases)=32
# estimating bias from koopman Theory!
# kl_div=Array(238.96185939, dtype=float64)
# running round i=3 with 1000 steps
# grid=[Array([ 145.76402723,  195.8704116 ,  245.97679596,  296.08318032,
#         346.18956468,  396.29594904,  446.40233341,  496.50871777,
#         546.61510213,  596.72148649,  646.82787085,  696.93425521,
#         747.04063958,  797.14702394,  847.2534083 ,  897.35979266,
#         947.46617702,  997.57256139, 1047.67894575, 1097.78533011,
#        1147.89171447, 1197.99809883, 1248.10448319, 1298.21086756,
#        1348.31725192, 1398.42363628, 1448.53002064, 1498.636405  ,
#        1548.74278937, 1598.84917373, 1648.95555809, 1699.06194245,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([7.79884801e-10], dtype=float64)
# len(biases)=32
# got exception  while collecting md 0, round 3, cv 0, marking as invalid
# got exception  while collecting md 1, round 3, cv 0, marking as invalid
# got exception  while collecting md 4, round 3, cv 0, marking as invalid
# got exception  while collecting md 6, round 3, cv 0, marking as invalid
# got exception  while collecting md 15, round 3, cv 0, marking as invalid
# got exception  while collecting md 20, round 3, cv 0, marking as invalid
# got exception  while collecting md 24, round 3, cv 0, marking as invalid
# got exception  while collecting md 25, round 3, cv 0, marking as invalid
# got exception  while collecting md 26, round 3, cv 0, marking as invalid
# got exception  while collecting md 27, round 3, cv 0, marking as invalid
# got exception  while collecting md 28, round 3, cv 0, marking as invalid
# got exception  while collecting md 29, round 3, cv 0, marking as invalid
# estimating bias from koopman Theory!
# kl_div=Array(84.30213876, dtype=float64)
# running round i=4 with 1000 steps
# grid=[Array([ 145.76402723,  195.8704116 ,  245.97679596,  296.08318032,
#         346.18956468,  396.29594904,  446.40233341,  496.50871777,
#         546.61510213,  596.72148649,  646.82787085,  696.93425521,
#         747.04063958,  797.14702394,  847.2534083 ,  897.35979266,
#         947.46617702,  997.57256139, 1047.67894575, 1097.78533011,
#        1147.89171447, 1197.99809883, 1248.10448319, 1298.21086756,
#        1348.31725192, 1398.42363628, 1448.53002064, 1498.636405  ,
#        1548.74278937, 1598.84917373, 1648.95555809, 1699.06194245,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([7.79884801e-10], dtype=float64)
# len(biases)=32
# Process WorkQueue-Submit-Process:
# Process WorkQueue-Submit-Process:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scheme.inner_loop(
#       2     steps=steps,
#       3     n=32,
#       4     convergence_kl=1e-4,
#       5     chunk_size=100,
#       6     eps_umbrella=0.10,
#       7     max_bias=max_bias,
#       8     samples_per_bin=samples_per_bin,
#       9     min_samples_per_bin=min_samples_per_bin,
#      10 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:239, in Scheme.inner_loop(self, rnds, convergence_kl, steps, K, update_metric, n, samples_per_bin, min_samples_per_bin, init_max_grad, plot, choice, fes_bias_rnds, scale_n, cv_round, chunk_size, eps_umbrella, plot_margin, enforce_min_traj_length, recalc_cv, only_finished, plot_umbrella, max_bias, n_max_fes, thermolib, macro_chunk, T_scale, koopman, lag_n, koopman_wham, out, direct_bias, init, first_round_without_bias)
#     236 if without_bias:
#     237     print(f"running first round wihtout biases")
# --> 239 self.grid_umbrella(
#     240     steps=steps,
#     241     n=n,
#     242     k=K,
#     243     plot=plot_umbrella,
#     244     scale_n=scale_n,
#     245     cv_round=cv_round,
#     246     ignore_invalid=False,
#     247     eps=eps_umbrella if not without_bias else 1,
#     248     min_traj_length=steps if (i > 1 and enforce_min_traj_length) else None,
#     249     recalc_cv=recalc_cv,
#     250     only_finished=i > 1 and only_finished,
#     251     chunk_size=chunk_size,
#     252     T_scale=T_scale,
#     253     # use_fes_bias=True,
#     254 )
#     256 prev_bias = self.rounds.get_bias(c=cv_round, r=i)
#     258 new_bias = self.FESBias(
#     259     plot=plot,
#     260     samples_per_bin=samples_per_bin,
#    (...)    279     direct_bias=direct_bias,
#     280 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:138, in Scheme.grid_umbrella(self, steps, k, n, max_grad, plot, scale_n, cv_round, ignore_invalid, eps, min_traj_length, recalc_cv, only_finished, chunk_size, T_scale)
#     135 else:
#     136     sp0 = None
# --> 138 self.rounds.run_par(
#     139     biases=biases,
#     140     steps=steps,
#     141     plot=plot,
#     142     cv_round=cv_round,
#     143     ignore_invalid=ignore_invalid,
#     144     min_traj_length=min_traj_length,
#     145     recalc_cv=recalc_cv,
#     146     only_finished=only_finished,
#     147     sp0=sp0,
#     148     chunk_size=chunk_size,
#     149     T_scale=T_scale,
#     150     # use_fes_bias=True,
#     151 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/base/rounds.py:2012, in Rounds.run_par(self, biases, steps, plot, KEY, sp0, ignore_invalid, md_trajs, cv_round, wait_for_plots, min_traj_length, recalc_cv, only_finished, profile, chunk_size, T_scale, macro_chunk, lag_n, use_fes_bias)
#    1987 common_md_name = self.full_path(self._name_md(c=cv_round, r=r))
#    1989 pn = self.path(c=cv_round, r=r)
#    1991 out = bash_app_python(
#    1992     Rounds._get_init,
#    1993     executors=Executors.training,
#    1994 )(
#    1995     rounds=self,
#    1996     KEY=KEY,
#    1997     ignore_invalid=ignore_invalid,
#    1998     only_finished=only_finished,
#    1999     min_traj_length=min_traj_length,
#    2000     recalc_cv=recalc_cv,
#    2001     T_scale=T_scale,
#    2002     chunk_size=chunk_size,
#    2003     md_trajs=md_trajs,
#    2004     cv_round=cv_round,
#    2005     biases=biases,
#    2006     sp0=sp0,
#    2007     common_bias_name=common_bias_name,
#    2008     r=r,
#    2009     execution_folder=pn,
#    2010     macro_chunk=macro_chunk,
#    2011     lag_n=lag_n,
# -> 2012 ).result()
#    2014 from parsl.dataflow.dflow import AppFuture
#    2016 tasks: list[tuple[int, AppFuture]] | None = None
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import ase


from IMLCV.base.UnitsConstants import electronvolt,kjmol,kelvin,boltzmann

kjmol

# ase.units.kJ/ase.units.mol
# Out:
# 0.0003808799176039228

# %%
300 * kelvin*boltzmann
# Out:
# 0.000950044621540259

# %%
from IMLCV.base.UnitsConstants import kjmol

new_bias = scheme.FESBias(
    thermolib=False,
    n_max=1e5,
    # start_r=0,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)

scheme.rounds.add_round(bias=new_bias)
# Out:
# estimating bias from koopman Theory!
