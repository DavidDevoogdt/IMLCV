# %%
# %load_ext autoreload

# %autoreload 2

# %%
from IMLCV.configs.config_general import config

config(

    singlepoint_nodes=2,
    walltime="12:00:00",
    bootstrap=False,
    training_cores=16,

)
# Out:
# ROOT_DIR=PosixPath('/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV')
# node
# stevin
# executor='work_queue'
# wall_time_s=14160.0
# executor='work_queue'
# wall_time_s=42960.0
# executor='work_queue'
# wall_time_s=14160.0
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor reference_None failed due to: Workqueue Submit Process is not alive
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# Exception in thread WorkQueue-collector-thread:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     _threading_Thread_run(self)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 725, in _collect_work_queue_results
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor default_None failed due to: Workqueue Submit Process is not alive
#     raise ExecutorError(self, "Workqueue Submit Process is not alive")
# parsl.executors.errors.ExecutorError: Executor training_None failed due to: Workqueue Submit Process is not alive

# %%
from IMLCV.examples.example_systems import toy_periodic_phase_trans
md,refs = toy_periodic_phase_trans()

refs[0].volume()
# Out:
# Array(182.20503404, dtype=float64)

# %%
md.run(1000)
# Out:
# running for 1000 steps!
# Both thermostat and barostat are present separately and will be merged
# Temperature coupling achieved through Langevin thermostat
# Pressure coupling achieved through Langevin barostat
#    step   | cons err | e_pot[Kj/mol] |e_bias[Kj/mol] |  P[bar]  |   T[K]   |walltime[s]||∇ₓUᵇ|[Kj/Å] |    CV
# ================================================================================================================
#        100|    0.0015|     7.00088123|     0.00000000  -27082.55     295.07        6.31|         0.00| [114.43217057]
#        200|    0.0016|     6.01809938|     0.00000000  -20689.99     335.15       10.58|         0.00| [145.5692478]
#        300|    0.0017|    12.02370745|     0.00000000   19786.29     275.98       14.75|         0.00| [93.81863793]
#        400|    0.0016|    12.29780299|     0.00000000  -22359.71     158.19       18.91|         0.00| [127.39746694]
#        500|    0.0017|     7.83545202|     0.00000000   -4414.08     223.99       23.10|         0.00| [80.700748]
#        600|    0.0017|    12.75760896|     0.00000000  -12763.37     332.61       27.30|         0.00| [102.24761193]
#        700|    0.0019|    18.03340992|     0.00000000  -14742.57     391.34       31.58|         0.00| [93.19865063]
#        800|    0.0025|    30.84986169|     0.00000000  -59334.53     395.60       36.52|         0.00| [112.91321865]
#        900|    0.0028|     4.03211519|     0.00000000   10091.18     267.65       41.09|         0.00| [111.48098142]
#       1000|    0.0028|    20.27447882|     0.00000000  -44273.56     228.94       45.27|         0.00| [119.23488198]

# %%
from ase.visualize import view
view(md.sp.canonicalize()[0].to_ase(md.static_trajectory_info).repeat(2), viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 12.0">
#     <group/>
#   </viewpoint>
#   <transform translation="-3.0 -3.0 -3.0">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 6.0 0.0 0.0 6.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 6.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 6.0 0.0 0.0 6.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 0.0 6.0 0.0 0.0 6.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 6.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 6.0 0.0 0.0 6.0 0.0 6.0 0.0 0.0 6.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="0.5238301701900396 1.8936116511789616 2.6388678753228816">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.0370092196140974 1.4666146479018696 2.660943917132069">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.8155300304833065 0.37487687793415714 2.669408681164994">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.282614801507717 0.008247415282483626 2.8183434360630626">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.6592109129643303 1.3074452690151908 1.1810325346274078">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.087061719686817 1.7889442224778187 1.0485441035498086">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.8738675352728824 2.765403369279013 1.222498864923114">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.4197934326363915 0.3218191567935584 1.2726683723660557">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.5238301701900396 1.8936116511789616 5.638867875322882">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.0370092196140974 1.4666146479018696 5.6609439171320695">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.8155300304833065 0.37487687793415714 5.6694086811649935">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.282614801507717 0.008247415282483626 5.818343436063063">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.6592109129643303 1.3074452690151908 4.181032534627407">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.087061719686817 1.7889442224778187 4.048544103549808">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.8738675352728824 2.765403369279013 4.222498864923114">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.4197934326363915 0.3218191567935584 4.272668372366056">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.5238301701900396 4.893611651178961 2.6388678753228816">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.0370092196140974 4.46661464790187 2.660943917132069">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.8155300304833065 3.374876877934157 2.669408681164994">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.282614801507717 3.0082474152824834 2.8183434360630626">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.6592109129643303 4.307445269015191 1.1810325346274078">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.5

# %%
from pathlib import Path

from IMLCV.base.rounds import Rounds
from IMLCV.examples.example_systems import toy_periodic_phase_trans
from IMLCV.scheme import Scheme

folder = Path("perovskites")/"toy_periodic_2"

if folder.exists():
    scheme = Scheme( rounds= Rounds.create(folder=folder, copy=False, new_folder=False))

else:
    md,refs = toy_periodic_phase_trans()
    

    scheme = Scheme.from_refs(mde=md, refs=sum(*refs), folder=folder,steps=1000,)

# %%
from IMLCV.base.UnitsConstants import kelvin,boltzmann, kjmol,angstrom

300*kelvin*boltzmann/kjmol
# Out:
# 2.494341595946812

# %%
steps=2000

chunk_size=100

max_bias=150 * kjmol
samples_per_bin=20
min_samples_per_bin=5

# %%
scheme.inner_loop(
    steps=steps,
    n=16,
    convergence_kl=1e-4,
    chunk_size=100,
    eps_umbrella=0.10,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)
# Out:
# cv_round=0
# i_0=1
# running round i=1 with 2000 steps
# grid=[Array([ 145.76402723,  245.97679596,  346.18956468,  446.40233341,
#         546.61510213,  646.82787085,  747.04063958,  847.2534083 ,
#         947.46617702, 1047.67894575, 1147.89171447, 1248.10448319,
#        1348.31725192, 1448.53002064, 1548.74278937, 1648.95555809,
#        1749.16832681], dtype=float64)]
# k*kjmol=Array([1.949712e-10], dtype=float64)
# len(biases)=16
# got exception  while collecting md 0, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=0 because traj file does not exist
# got exception  while collecting md 1, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=1 because traj file does not exist
# got exception  while collecting md 2, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=2 because traj file does not exist
# got exception  while collecting md 3, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=3 because traj file does not exist
# got exception  while collecting md 4, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=4 because traj file does not exist
# got exception  while collecting md 5, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=5 because traj file does not exist
# got exception  while collecting md 6, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=6 because traj file does not exist
# got exception  while collecting md 7, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=7 because traj file does not exist
# got exception  while collecting md 8, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=8 because traj file does not exist
# got exception  while collecting md 9, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=9 because traj file does not exist
# got exception  while collecting md 10, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=10 because traj file does not exist
# got exception  while collecting md 11, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=11 because traj file does not exist
# got exception  while collecting md 12, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=12 because traj file does not exist
# got exception  while collecting md 13, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=13 because traj file does not exist
# got exception  while collecting md 14, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=14 because traj file does not exist
# got exception  while collecting md 15, round 1, cv 0, marking as invalid
# cannot invalidate data for c=0 r=1 i=15 because traj file does not exist
# estimating bias from koopman Theory!
# Process WorkQueue-Submit-Process:
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 861, in _work_queue_submit_wait
#     task = task_queue.get(timeout=1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# Process WorkQueue-Submit-Process:
# Process WorkQueue-Submit-Process:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 970, in _work_queue_submit_wait
#     t = q.wait(1)
#         ^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1914, in wait
#     return self.wait_for_tag(None, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1928, in wait_for_tag
#     task_pointer = work_queue_wait_for_tag(self._work_queue, tag, timeout)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/process_loggers.py", line 26, in wrapped
#     r = func(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/cwork_queue.py", line 543, in work_queue_wait_for_tag
#     return _cwork_queue.work_queue_wait_for_tag(q, tag, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/parsl/executors/workqueue/executor.py", line 970, in _work_queue_submit_wait
#     t = q.wait(1)
#         ^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1914, in wait
#     return self.wait_for_tag(None, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/work_queue.py", line 1928, in wait_for_tag
#     task_pointer = work_queue_wait_for_tag(self._work_queue, tag, timeout)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/site-packages/ndcctools/cwork_queue.py", line 543, in work_queue_wait_for_tag
#     return _cwork_queue.work_queue_wait_for_tag(q, tag, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# warning: using plain-text when communicating with workers.
# warning: use encryption with a key and cert when creating the manager.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scheme.inner_loop(
#       2     steps=steps,
#       3     n=16,
#       4     convergence_kl=1e-4,
#       5     chunk_size=100,
#       6     eps_umbrella=0.10,
#       7     max_bias=max_bias,
#       8     samples_per_bin=samples_per_bin,
#       9     min_samples_per_bin=min_samples_per_bin,
#      10 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:258, in Scheme.inner_loop(self, rnds, convergence_kl, steps, K, update_metric, n, samples_per_bin, min_samples_per_bin, init_max_grad, plot, choice, fes_bias_rnds, scale_n, cv_round, chunk_size, eps_umbrella, plot_margin, enforce_min_traj_length, recalc_cv, only_finished, plot_umbrella, max_bias, n_max_fes, thermolib, macro_chunk, T_scale, koopman, lag_n, koopman_wham, out, direct_bias, init, first_round_without_bias)
#     239 self.grid_umbrella(
#     240     steps=steps,
#     241     n=n,
#    (...)    253     # use_fes_bias=True,
#     254 )
#     256 prev_bias = self.rounds.get_bias(c=cv_round, r=i)
# --> 258 new_bias = self.FESBias(
#     259     plot=plot,
#     260     samples_per_bin=samples_per_bin,
#     261     min_samples_per_bin=min_samples_per_bin,
#     262     choice=choice,
#     263     num_rnds=fes_bias_rnds,
#     264     cv_round=cv_round,
#     265     chunk_size=chunk_size,
#     266     min_traj_length=steps if enforce_min_traj_length else None,
#     267     margin=plot_margin,
#     268     only_finished=only_finished,
#     269     max_bias=max_bias,
#     270     n_max=n_max_fes,
#     271     thermolib=thermolib,
#     272     macro_chunk=macro_chunk,
#     273     vmax=max_bias,
#     274     T_scale=T_scale,
#     275     koopman=koopman,
#     276     lag_n=lag_n,
#     277     koopman_wham=koopman_wham,
#     278     out=out,
#     279     direct_bias=direct_bias,
#     280 )
#     282 self.rounds.add_round(bias=new_bias, c=cv_round)
#     284 kl_div = self.md.bias.kl_divergence(
#     285     prev_bias,
#     286     T=self.rounds.T,
#     287     symmetric=True,
#     288 )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/scheme.py:67, in Scheme.FESBias(self, rnd, cv_round, chunk_size, **plotkwargs)
#      57 def FESBias(
#      58     self,
#      59     rnd: int | None = None,
#    (...)     62     **plotkwargs,
#      63 ) -> Bias:
#      64     """replace the current md bias with the computed FES from current
#      65     round."""
# ---> 67     return Observable.create(
#      68         self.rounds,
#      69         rnd=rnd,
#      70         cv_round=cv_round,
#      71     ).fes_bias(
#      72         chunk_size=chunk_size,
#      73         **plotkwargs,
#      74     )
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/base/Observable.py:620, in Observable.fes_bias(self, plot, fes, max_bias, choice, num_rnds, start_r, rbf_kernel, rbf_degree, samples_per_bin, min_samples_per_bin, chunk_size, macro_chunk, update_bounding_box, n_max, min_traj_length, margin, only_finished, shmap, thermolib, lag_n, out, T_scale, vmax, koopman, verbose, koopman_wham, executors, direct_bias)
#     617 else:
#     618     print("estimating bias from koopman Theory!")
# --> 620     fes_bias_tot = self.fes_nd_weights(
#     621         num_rnds=num_rnds,
#     622         out=out,
#     623         lag_n=lag_n,
#     624         start_r=start_r,
#     625         min_traj_length=min_traj_length,
#     626         only_finished=only_finished,
#     627         chunk_size=chunk_size,
#     628         macro_chunk=macro_chunk,
#     629         T_scale=T_scale,
#     630         n_max=n_max,
#     631         koopman=koopman,
#     632         # divide_by_histogram=divide_by_histogram,
#     633         verbose=verbose,
#     634         max_bias=max_bias,
#     635         kooopman_wham=koopman_wham,
#     636         samples_per_bin=samples_per_bin,
#     637         min_samples_per_bin=min_samples_per_bin,
#     638         executors=executors,
#     639         direct_bias=direct_bias,
#     640     )
#     642 return fes_bias_tot
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/IMLCV/IMLCV/src/IMLCV/base/Observable.py:536, in Observable.fes_nd_weights(self, num_rnds, out, lag_n, start_r, min_traj_length, only_finished, chunk_size, macro_chunk, T_scale, n_max, cv_round, directory, koopman, verbose, max_bias, kooopman_wham, samples_per_bin, min_samples_per_bin, executors, direct_bias)
#     526 if executors is None:
#     527     return Observable._fes_nd_weights(**kwargs)
#     529 return bash_app_python(
#     530     Observable._fes_nd_weights,
#     531     executors=Executors.training,
#     532     remove_stdout=False,
#     533 )(
#     534     **kwargs,
#     535     execution_folder=directory,
# --> 536 ).result()
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /kyukon/scratch/gent/vo/000/gvo00003/vsc43693/envs/condaenv/py312/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import ase


from IMLCV.base.UnitsConstants import electronvolt,kjmol,kelvin,boltzmann

kjmol

# ase.units.kJ/ase.units.mol
# Out:
# 0.0003808799176039228

# %%
300 * kelvin*boltzmann
# Out:
# 0.000950044621540259

# %%
from IMLCV.base.UnitsConstants import kjmol

new_bias = scheme.FESBias(
    thermolib=False,
    n_max=1e5,
    # start_r=0,
    max_bias=max_bias,
    samples_per_bin=samples_per_bin,
    min_samples_per_bin=min_samples_per_bin,
)

scheme.rounds.add_round(bias=new_bias)
# Out:
# estimating bias from koopman Theory!
